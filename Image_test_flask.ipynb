# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from flask import Flask, abort, request, jsonify
import base64

# %%
# 经测试，base64
with open('./test_pics/jmc-01.jpg', 'rb') as f:
    picData = f.read()
    bb64 = base64.b64encode(picData)

ori = base64.b64decode(bb64)

print (picData)
# Out:
# b'\xff\xd8\xff\xe1\x016Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00b\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00j\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x1c\x00\x00\x00r\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\x8e\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xa4\x00\x00\x00\xd0\x00-\xc6\xc0\x00\x00\'\x10\x00-\xc6\xc0\x00\x00\'\x10Adobe Photoshop CS5 Windows\x002014:11:10 14:57:08\x00\x00\x00\x00\x03\xa0\x01\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x03 \xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x03"\x00\x00\x00\x00\x00\x00\x00\x06\x01\x03\x00\x03\x00\x00\x00\x01\x00\x06\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x01\x1e\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x01&\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x02\x01\x00\x04\x00\x00\x00\x01\x00\x00\x01.\x02\x02\x00\x04\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
print (ori)
# Out:
# b'\xff\xd8\xff\xe1\x016Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00b\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00j\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x1c\x00\x00\x00r\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\x8e\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xa4\x00\x00\x00\xd0\x00-\xc6\xc0\x00\x00\'\x10\x00-\xc6\xc0\x00\x00\'\x10Adobe Photoshop CS5 Windows\x002014:11:10 14:57:08\x00\x00\x00\x00\x03\xa0\x01\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x03 \xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x03"\x00\x00\x00\x00\x00\x00\x00\x06\x01\x03\x00\x03\x00\x00\x00\x01\x00\x06\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x01\x1e\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x01&\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x02\x01\x00\x04\x00\x00\x00\x01\x00\x00\x01.\x02\x02\x00\x04\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
###  把图片编码为base64格式字符串

# with open (r'./test_pics/jmc-01.jpg','rb') as f : 
#     ls_f = base64.b64encode(f.read()) 
# print (ls_f)

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import os, base64

icon = open('ya.png','rb')
iconData = icon.read()
iconData = base64.b64encode(iconData)
LIMIT = 60
liIcon = []
while True:
        sLimit = iconData[:LIMIT]
        iconData = iconData[LIMIT:]
        liIcon.append('\'%s\'' %sLimit)
        if len(sLimit) < LIMIT:
                break
print os.linesep.join(liIcon)

# %%
app = Flask(__name__)

#  测试数据暂时存放
tasks = []
